# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
G = nx.barabasi_albert_graph(100,2)

# %%
nx.draw_spring(G)

# %%
plt.hist([v for k,v in nx.degree(G)])
# Out:
# (array([79., 12.,  5.,  1.,  2.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 2.,  5.,  8., 11., 14., 17., 20., 23., 26., 29., 32.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(nx.centrality.betweenness_centrality(G).values())
# Out:
# (array([92.,  4.,  2.,  1.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([0.        , 0.05111563, 0.10223126, 0.15334689, 0.20446252,
#         0.25557815, 0.30669378, 0.35780941, 0.40892503, 0.46004066,
#         0.51115629]),
#  <BarContainer object of 10 artists>)

# %%
nx.diameter(G)
# Out:
# 5

# %%
nx.cluster.average_clustering(G)
# Out:
# 0.1140410731741377

# %%
nodes = list(range(100))

df = pd.DataFrame({'from' : np.random.choice(nodes, 100),
                  'to' : np.random.choice(nodes,100)})

# %%
df
# Out:
#     from  to
# 0     66  58
# 1     33  57
# 2     18  26
# 3      2   0
# 4     59  21
# ..   ...  ..
# 95    36   2
# 96    79  44
# 97    82  20
# 98    24  66
# 99     8  81
#
# [100 rows x 2 columns]

# %%
G = nx.from_pandas_edgelist(df, source="from", target="to")

# %%
nx.draw(G)

# %%
plt.hist([v for k,v in nx.degree(G)])
# Out:
# (array([26.,  0., 29.,  0.,  0., 18.,  0.,  7.,  0.,  6.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)
